# %%
#Loading Library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#load dataset

# %%
data=pd.read_csv(r"C:\Users\asus\Downloads\hypothyroid.csv")

# %%
data.head()
# Out:
#   age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0  41   F            f                  f                         f    f
# 1  23   F            f                  f                         f    f
# 2  46   M            f                  f                         f    f
# 3  70   F            t                  f                         f    f
# 4  70   F            f                  f                         f    f
#
#   pregnant thyroid surgery I131 treatment query hypothyroid  ... TT4 measured  \
# 0        f               f              f                 f  ...            t
# 1        f               f              f                 f  ...            t
# 2        f               f              f                 f  ...            t
# 3        f               f              f                 f  ...            t
# 4        f               f              f                 f  ...            t
#
#    TT4 T4U measured   T4U FTI measured  FTI TBG measured TBG referral source  \
# 0  125            t  1.14            t  109            f   ?            SVHC
# 1  102            f     ?            f    ?            f   ?           other
# 2  109            t  0.91            t  120            f   ?           other
# 3  175            f     ?            f    ?            f   ?           other
# 4   61            t  0.87            t   70            f   ?             SVI
#
#   binaryClass
# 0           P
# 1           P
# 2           P
# 3           P
# 4           P
#
# [5 rows x 30 columns]

# %%
pd.Categorical(data['on thyroxine'])
# Out:
# ['f', 'f', 'f', 't', 'f', ..., 'f', 'f', 'f', 'f', 'f']
# Length: 3772
# Categories (2, object): ['f', 't']

# %%
# try to understand the features

# %%
data.shape
# Out:
# (3772, 30)

# %%
data.isnull().sum()
# Out:
# age                          0
# sex                          0
# on thyroxine                 0
# query on thyroxine           0
# on antithyroid medication    0
# sick                         0
# pregnant                     0
# thyroid surgery              0
# I131 treatment               0
# query hypothyroid            0
# query hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH measured                 0
# TSH                          0
# T3 measured                  0
# T3                           0
# TT4 measured                 0
# TT4                          0
# T4U measured                 0
# T4U                          0
# FTI measured                 0
# FTI                          0
# TBG measured                 0
# TBG                          0
# referral source              0
# binaryClass                  0
# dtype: int64

# %%
data.replace("?",np.nan,inplace=True);

# %%
data.head()
# Out:
#   age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0  41   F            f                  f                         f    f
# 1  23   F            f                  f                         f    f
# 2  46   M            f                  f                         f    f
# 3  70   F            t                  f                         f    f
# 4  70   F            f                  f                         f    f
#
#   pregnant thyroid surgery I131 treatment query hypothyroid  ... TT4 measured  \
# 0        f               f              f                 f  ...            t
# 1        f               f              f                 f  ...            t
# 2        f               f              f                 f  ...            t
# 3        f               f              f                 f  ...            t
# 4        f               f              f                 f  ...            t
#
#    TT4 T4U measured   T4U FTI measured  FTI TBG measured TBG referral source  \
# 0  125            t  1.14            t  109            f NaN            SVHC
# 1  102            f   NaN            f  NaN            f NaN           other
# 2  109            t  0.91            t  120            f NaN           other
# 3  175            f   NaN            f  NaN            f NaN           other
# 4   61            t  0.87            t   70            f NaN             SVI
#
#   binaryClass
# 0           P
# 1           P
# 2           P
# 3           P
# 4           P
#
# [5 rows x 30 columns]

# %%
data.isnull().sum()
# Out:
# age                             1
# sex                           150
# on thyroxine                    0
# query on thyroxine              0
# on antithyroid medication       0
# sick                            0
# pregnant                        0
# thyroid surgery                 0
# I131 treatment                  0
# query hypothyroid               0
# query hyperthyroid              0
# lithium                         0
# goitre                          0
# tumor                           0
# hypopituitary                   0
# psych                           0
# TSH measured                    0
# TSH                           369
# T3 measured                     0
# T3                            769
# TT4 measured                    0
# TT4                           231
# T4U measured                    0
# T4U                           387
# FTI measured                    0
# FTI                           385
# TBG measured                    0
# TBG                          3772
# referral source                 0
# binaryClass                     0
# dtype: int64

# %%
missing_values = data.isnull().sum().sort_values(ascending=False)
per=(data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
pd.concat([missing_values,per],keys=['Total_Missing_Values','Percentage'],axis=1)
# Out:
#                            Total_Missing_Values  Percentage
# TBG                                        3772    1.000000
# T3                                          769    0.203871
# T4U                                         387    0.102598
# FTI                                         385    0.102068
# TSH                                         369    0.097826
# TT4                                         231    0.061241
# sex                                         150    0.039767
# age                                           1    0.000265
# query hypothyroid                             0    0.000000
# I131 treatment                                0    0.000000
# thyroid surgery                               0    0.000000
# pregnant                                      0    0.000000
# on antithyroid medication                     0    0.000000
# sick                                          0    0.000000
# lithium                                       0    0.000000
# query on thyroxine                            0    0.000000
# on thyroxine                                  0    0.000000
# query hyperthyroid                            0    0.000000
# binaryClass                                   0    0.000000
# goitre                                        0    0.000000
# tumor                                         0    0.000000
# referral source                               0    0.000000
# psych                                         0    0.000000
# TSH measured                                  0    0.000000
# T3 measured                                   0    0.000000
# TT4 measured                                  0    0.000000
# T4U measured                                  0    0.000000
# FTI measured                                  0    0.000000
# TBG measured                                  0    0.000000
# hypopituitary                                 0    0.000000

# %%
data=data.drop('TBG',axis=1)

# %%
data.head()
# Out:
#   age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0  41   F            f                  f                         f    f
# 1  23   F            f                  f                         f    f
# 2  46   M            f                  f                         f    f
# 3  70   F            t                  f                         f    f
# 4  70   F            f                  f                         f    f
#
#   pregnant thyroid surgery I131 treatment query hypothyroid  ...   T3  \
# 0        f               f              f                 f  ...  2.5
# 1        f               f              f                 f  ...    2
# 2        f               f              f                 f  ...  NaN
# 3        f               f              f                 f  ...  1.9
# 4        f               f              f                 f  ...  1.2
#
#   TT4 measured  TT4 T4U measured   T4U FTI measured  FTI TBG measured  \
# 0            t  125            t  1.14            t  109            f
# 1            t  102            f   NaN            f  NaN            f
# 2            t  109            t  0.91            t  120            f
# 3            t  175            f   NaN            f  NaN            f
# 4            t   61            t  0.87            t   70            f
#
#   referral source binaryClass
# 0            SVHC           P
# 1           other           P
# 2           other           P
# 3           other           P
# 4             SVI           P
#
# [5 rows x 29 columns]

# %%
data.shape
# Out:
# (3772, 29)

# %%
data.replace(['t','f'],['1','0'],inplace=True)

# %%
data.head()
# Out:
#   age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0  41   F            0                  0                         0    0
# 1  23   F            0                  0                         0    0
# 2  46   M            0                  0                         0    0
# 3  70   F            1                  0                         0    0
# 4  70   F            0                  0                         0    0
#
#   pregnant thyroid surgery I131 treatment query hypothyroid  ...   T3  \
# 0        0               0              0                 0  ...  2.5
# 1        0               0              0                 0  ...    2
# 2        0               0              0                 0  ...  NaN
# 3        0               0              0                 0  ...  1.9
# 4        0               0              0                 0  ...  1.2
#
#   TT4 measured  TT4 T4U measured   T4U FTI measured  FTI TBG measured  \
# 0            1  125            1  1.14            1  109            0
# 1            1  102            0   NaN            0  NaN            0
# 2            1  109            1  0.91            1  120            0
# 3            1  175            0   NaN            0  NaN            0
# 4            1   61            1  0.87            1   70            0
#
#   referral source binaryClass
# 0            SVHC           P
# 1           other           P
# 2           other           P
# 3           other           P
# 4             SVI           P
#
# [5 rows x 29 columns]

# %%
data.dtypes
# Out:
# age                          object
# sex                          object
# on thyroxine                 object
# query on thyroxine           object
# on antithyroid medication    object
# sick                         object
# pregnant                     object
# thyroid surgery              object
# I131 treatment               object
# query hypothyroid            object
# query hyperthyroid           object
# lithium                      object
# goitre                       object
# tumor                        object
# hypopituitary                object
# psych                        object
# TSH measured                 object
# TSH                          object
# T3 measured                  object
# T3                           object
# TT4 measured                 object
# TT4                          object
# T4U measured                 object
# T4U                          object
# FTI measured                 object
# FTI                          object
# TBG measured                 object
# referral source              object
# binaryClass                  object
# dtype: object

# %%
missing_values = data.isnull().sum().sort_values(ascending=False)
per=(data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
pd.concat([missing_values,per],keys=['Total_Missing_Values','Percentage'],axis=1)
# Out:
#                            Total_Missing_Values  Percentage
# T3                                          769    0.203871
# T4U                                         387    0.102598
# FTI                                         385    0.102068
# TSH                                         369    0.097826
# TT4                                         231    0.061241
# sex                                         150    0.039767
# age                                           1    0.000265
# query hypothyroid                             0    0.000000
# I131 treatment                                0    0.000000
# thyroid surgery                               0    0.000000
# pregnant                                      0    0.000000
# on antithyroid medication                     0    0.000000
# sick                                          0    0.000000
# lithium                                       0    0.000000
# query on thyroxine                            0    0.000000
# on thyroxine                                  0    0.000000
# query hyperthyroid                            0    0.000000
# binaryClass                                   0    0.000000
# goitre                                        0    0.000000
# tumor                                         0    0.000000
# referral source                               0    0.000000
# psych                                         0    0.000000
# TSH measured                                  0    0.000000
# T3 measured                                   0    0.000000
# TT4 measured                                  0    0.000000
# T4U measured                                  0    0.000000
# FTI measured                                  0    0.000000
# TBG measured                                  0    0.000000
# hypopituitary                                 0    0.000000

# %%
col_fill=per[per>0].keys()

# %%
col_fill
# Out:
# Index(['T3', 'T4U', 'FTI', 'TSH', 'TT4', 'sex', 'age'], dtype='object')

# %%
data['T3']=data['T3'].fillna(data['T3'].dropna().mode().values[0])
data['T4U']=data['T4U'].fillna(data['T4U'].dropna().mode().values[0])
data['FTI']=data['FTI'].fillna(data['FTI'].dropna().mode().values[0])
data['TSH']=data['TSH'].fillna(data['TSH'].dropna().mode().values[0])
data['TT4']=data['TT4'].fillna(data['TT4'].dropna().mode().values[0])
data['sex']=data['sex'].fillna(data['sex'].dropna().mode().values[0])
data['age']=data['age'].fillna(data['age'].dropna().mode().values[0])

# %%
missing_values = data.isnull().sum().sort_values(ascending=False)
per=(data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
pd.concat([missing_values,per],keys=['Total_Missing_Values','Percentage'],axis=1)
# Out:
#                            Total_Missing_Values  Percentage
# binaryClass                                   0         0.0
# tumor                                         0         0.0
# sex                                           0         0.0
# on thyroxine                                  0         0.0
# query on thyroxine                            0         0.0
# on antithyroid medication                     0         0.0
# sick                                          0         0.0
# pregnant                                      0         0.0
# thyroid surgery                               0         0.0
# I131 treatment                                0         0.0
# query hypothyroid                             0         0.0
# query hyperthyroid                            0         0.0
# lithium                                       0         0.0
# goitre                                        0         0.0
# hypopituitary                                 0         0.0
# referral source                               0         0.0
# psych                                         0         0.0
# TSH measured                                  0         0.0
# TSH                                           0         0.0
# T3 measured                                   0         0.0
# T3                                            0         0.0
# TT4 measured                                  0         0.0
# TT4                                           0         0.0
# T4U measured                                  0         0.0
# T4U                                           0         0.0
# FTI measured                                  0         0.0
# FTI                                           0         0.0
# TBG measured                                  0         0.0
# age                                           0         0.0

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.head()
# Out:
#   age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0  41   F            0                  0                         0    0
# 1  23   F            0                  0                         0    0
# 2  46   M            0                  0                         0    0
# 3  70   F            1                  0                         0    0
# 4  70   F            0                  0                         0    0
#
#   pregnant thyroid surgery I131 treatment query hypothyroid  ...   T3  \
# 0        0               0              0                 0  ...  2.5
# 1        0               0              0                 0  ...    2
# 2        0               0              0                 0  ...    2
# 3        0               0              0                 0  ...  1.9
# 4        0               0              0                 0  ...  1.2
#
#   TT4 measured  TT4 T4U measured   T4U FTI measured  FTI TBG measured  \
# 0            1  125            1  1.14            1  109            0
# 1            1  102            0  0.99            0  100            0
# 2            1  109            1  0.91            1  120            0
# 3            1  175            0  0.99            0  100            0
# 4            1   61            1  0.87            1   70            0
#
#   referral source binaryClass
# 0            SVHC           P
# 1           other           P
# 2           other           P
# 3           other           P
# 4             SVI           P
#
# [5 rows x 29 columns]

# %%
data.describe()
# Out:
#          age   sex on thyroxine query on thyroxine on antithyroid medication  \
# count   3772  3772         3772               3772                      3772
# unique    93     2            2                  2                         2
# top       59     F            0                  0                         0
# freq      96  2630         3308               3722                      3729
#
#         sick pregnant thyroid surgery I131 treatment query hypothyroid  ...  \
# count   3772     3772            3772           3772              3772  ...
# unique     2        2               2              2                 2  ...
# top        0        0               0              0                 0  ...
# freq    3625     3719            3719           3713              3538  ...
#
#           T3 TT4 measured   TT4 T4U measured   T4U FTI measured   FTI  \
# count   3772         3772  3772         3772  3772         3772  3772
# unique    69            2   241            2   146            2   234
# top        2            1   101            1  0.99            1   100
# freq    1007         3541   302         3385   482         3387   458
#
#        TBG measured referral source binaryClass
# count          3772            3772        3772
# unique            1               5           2
# top               0           other           P
# freq           3772            2201        3481
#
# [4 rows x 29 columns]

# %%
pd.Categorical(data['referral source'])
# Out:
# ['SVHC', 'other', 'other', 'other', 'SVI', ..., 'other', 'SVI', 'other', 'SVI', 'other']
# Length: 3772
# Categories (5, object): ['STMW', 'SVHC', 'SVHD', 'SVI', 'other']

# %%
pd.Categorical(data['binaryClass'])
# Out:
# ['P', 'P', 'P', 'P', 'P', ..., 'P', 'P', 'P', 'P', 'P']
# Length: 3772
# Categories (2, object): ['N', 'P']

# %%
col=data.select_dtypes(include='object').keys()

# %%
len(col)
# Out:
# 29

# %%
data.dtypes
# Out:
# age                          object
# sex                          object
# on thyroxine                 object
# query on thyroxine           object
# on antithyroid medication    object
# sick                         object
# pregnant                     object
# thyroid surgery              object
# I131 treatment               object
# query hypothyroid            object
# query hyperthyroid           object
# lithium                      object
# goitre                       object
# tumor                        object
# hypopituitary                object
# psych                        object
# TSH measured                 object
# TSH                          object
# T3 measured                  object
# T3                           object
# TT4 measured                 object
# TT4                          object
# T4U measured                 object
# T4U                          object
# FTI measured                 object
# FTI                          object
# TBG measured                 object
# referral source              object
# binaryClass                  object
# dtype: object

# %%
for i,var in enumerate(col):
    plt.subplot(5,6,i+1)
    data[var].value_counts().plot(figsize=(30,20))

# %%
#Encoding
