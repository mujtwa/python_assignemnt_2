# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.DataFrame(np.random.randn(1000),index=pd.date_range('2019-06-07',periods=1000),columns=['value'])

# %%
df
# Out:
#                value
# 2019-06-07 -0.967053
# 2019-06-08  0.489109
# 2019-06-09  1.561969
# 2019-06-10  1.953713
# 2019-06-11  0.245913
# ...              ...
# 2022-02-26 -0.073096
# 2022-02-27 -1.159857
# 2022-02-28 -0.684069
# 2022-03-01 -1.650340
# 2022-03-02  1.778192
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['value']=df['value'].cumsum() # cumulative sum

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['value']=df['value']+10

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#                 value
# 2019-06-07   9.032947
# 2019-06-08   9.522056
# 2019-06-09  11.084025
# 2019-06-10  13.037738
# 2019-06-11  13.283652

# %%
iris_data=sns.load_dataset('iris')

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data.plot() # numerical columns
# Out:
# <AxesSubplot:>

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df=iris_data.drop('species',axis=1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[0].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot(kind="bar")
plt.ylabel("asdfd")
# Out:
# Text(0, 0.5, 'asdfd')

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1=sns.load_dataset('titanic')

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1['pclass'].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['pclass'].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df1['pclass'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df3=pd.DataFrame(np.random.randn(10,4),columns=['a','b','c','d'])

# %%
df3.plot()
# Out:
# <AxesSubplot:>

# %%
df3.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df3.head()
# Out:
#           a         b         c         d
# 0 -0.088281  1.624873  0.671018  0.068880
# 1  0.445603 -0.634969  0.811328  1.200623
# 2 -0.757227  1.895431 -1.451782 -0.496530
# 3 -0.264581 -2.088477  0.701560  0.237516
# 4 -1.226612 -0.226538  1.952075 -0.991854

# %%
df3.iloc[0].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df3.plot.line()
# Out:
# <AxesSubplot:>

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data.plot.hist()
plt.xlabel("Range...")
# Out:
# Text(0.5, 0, 'Range...')

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data['sepal_length'].hist()
# Out:
# <AxesSubplot:>

# %%
iris_data.hist();

# %%
iris_data['species'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris_data.plot(kind='hist',stacked=True,bins=50) # stacked = true -> shows overlap
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris_data.plot(kind='hist',stacked=True,bins=50,orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df3.hist()
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>]], dtype=object)

# %%
iris_data.hist(color="red",alpha=.4,figsize=(20,10)) # alpha density of color # hexa code also wa can use in color
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_data.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris_data.plot.scatter(x='sepal_length',y="petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris_data.plot.scatter(x='sepal_length',y="petal_length",color="red")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris_data.plot.scatter(x='sepal_length',y="petal_length",color="red",figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris_data.plot.scatter(x='sepal_length',y="petal_length",c="sepal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data.plot.scatter(x='sepal_length',y="petal_length",c="sepal_length",s=200)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris_data.plot.hexbin(x='sepal_length',y="petal_length",figsize=(10,8),C="sepal_length",gridsize=20)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
data = iris_data.iloc[0]

# %%
df4=iris_data.drop('species',axis=1)

# %%
data=df4.iloc[0]

# %%
data.plot.pie()
# Out:
# <AxesSubplot:ylabel='0'>

# %%
data1=df4.head(4).T

# %%
data1
# Out:
#                 0    1    2    3
# sepal_length  5.1  4.9  4.7  4.6
# sepal_width   3.5  3.0  3.2  3.1
# petal_length  1.4  1.4  1.3  1.5
# petal_width   0.2  0.2  0.2  0.2

# %%
df4
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df4.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='sepal_length'>,
#        <AxesSubplot:ylabel='sepal_width'>,
#        <AxesSubplot:ylabel='petal_length'>,
#        <AxesSubplot:ylabel='petal_width'>], dtype=object)

# %%
df6=df4.head().T

# %%
df6.plot.pie(subplots=True,figsize=(16,9))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>, <AxesSubplot:ylabel='3'>,
#        <AxesSubplot:ylabel='4'>], dtype=object)

# %%
df4
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
pd.plotting.scatter_matrix(df4,figsize=(16,9),color="red",alpha=.8)
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
pd.plotting.scatter_matrix(df4,figsize=(16,9),color="red",alpha=.8,diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
iris_data['sepal_length'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris_data['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris_data['sepal_length'].plot(style="r--",legend=True)
# Out:
# <AxesSubplot:>

# %%
# !pip install plotly
# !pip install cufflinks

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
py.__version__
# Out:
# '4.14.3'

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df4.iplot(size=40)
# Out:
# <div>                            <div id="ffaafdc2-0a2d-4401-9a0a-fb115f3dca48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
