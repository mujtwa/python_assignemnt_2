# %%
#load libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# load datasets

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
iris.sepal_length.plot(kind="hist")
plt.xlabel("sepal_length")

plt.subplot(2,2,2)
iris.sepal_width.plot(kind="hist")
plt.xlabel("sepal_width")

plt.subplot(2,2,3)
iris.petal_length.plot(kind="hist")
plt.xlabel("petal_length")

plt.subplot(2,2,4)
iris.petal_width.plot(kind="hist")
plt.xlabel("petal_width")
# Out:
# Text(0.5, 0, 'petal_width')

# %%
plt.figure(figsize=(16,9))
plt.scatter(x="sepal_width",y="sepal_length",data=iris,label="Setosa")

# %%
fig=iris[iris['species']=='setosa'].plot(kind="scatter",x="sepal_length",y="sepal_width",label="Setosa",color="blue",figsize=(16,9))
iris[iris['species']=='versicolor'].plot(kind="scatter",x="sepal_length",y="sepal_width",label="versicolor",ax=fig,color="red",figsize=(16,9))
iris[iris['species']=="virginica"].plot(kind="scatter",x="sepal_length",y="sepal_width",label="Virginica",ax=fig,color="green",figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(16,9))
fig=iris[iris['species']=='setosa'].plot(kind="scatter",x="petal_length",y="petal_width",color="blue",label="Setosa",figsize=(16,9))
iris[iris['species']=='versicolor'].plot(kind="scatter",x="petal_length",y="petal_width",color="red",ax=fig,label="Versicolor",figsize=(16,9))
iris[iris['species']=="virginica"].plot(kind="scatter",x="petal_length",y="petal_width",color="green",ax=fig,label="virginica",figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
plt.figure(figsize=(16,9))


plt.subplot(2,2,1)
sns.violinplot(x="species",y='sepal_width',data=iris)

plt.subplot(2,2,2)
sns.violinplot(x="species",y='sepal_length',data=iris)

plt.subplot(2,2,3)
sns.violinplot(x="species",y='petal_width',data=iris)

plt.subplot(2,2,4)
sns.violinplot(x="species",y='petal_length',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
# correlation matrix

# %%
sns.heatmap(iris.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
y=iris['species']
X=iris.drop('species',axis=1)

# %%
# one hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# one=OneHotEncoder()
# y=one.fit_transform(y)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
y=le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2)

# %%
print("Size of X_train : ",X_train.shape)
print("Size of X_test : ",X_test.shape)
print("Size of y_train : ",y_train.shape)
print("Size of y_test : ",y_test.shape)
# Out:
# Size of X_train :  (120, 4)
# Size of X_test :  (30, 4)
# Size of y_train :  (120,)
# Size of y_test :  (30,)

# %%
X_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 70            5.9          3.2           4.8          1.8
# 114           5.8          2.8           5.1          2.4
# 46            5.1          3.8           1.6          0.2
# 38            4.4          3.0           1.3          0.2
# 139           6.9          3.1           5.4          2.1

# %%
X_test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 136           6.3          3.4           5.6          2.4
# 32            5.2          4.1           1.5          0.1
# 29            4.7          3.2           1.6          0.2
# 10            5.4          3.7           1.5          0.2
# 107           7.3          2.9           6.3          1.8

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minscl=MinMaxScaler()
minscl.fit(X_train)
X_train_std=minscl.transform(X_train)
X_test_std=minscl.transform(X_test)

# %%
X_test_std
# Out:
# array([[ 0.58823529,  0.58333333,  0.77586207,  0.95833333],
#        [ 0.26470588,  0.875     ,  0.06896552,  0.        ],
#        [ 0.11764706,  0.5       ,  0.0862069 ,  0.04166667],
#        [ 0.32352941,  0.70833333,  0.06896552,  0.04166667],
#        [ 0.88235294,  0.375     ,  0.89655172,  0.70833333],
#        [ 0.23529412,  0.75      ,  0.06896552,  0.08333333],
#        [ 0.35294118,  0.16666667,  0.44827586,  0.375     ],
#        [ 0.35294118,  0.16666667,  0.46551724,  0.41666667],
#        [ 0.41176471,  0.20833333,  0.67241379,  0.79166667],
#        [ 0.08823529,  0.45833333,  0.06896552,  0.04166667],
#        [ 1.05882353,  0.75      ,  0.9137931 ,  0.79166667],
#        [ 0.85294118,  0.66666667,  0.86206897,  1.        ],
#        [ 0.23529412,  0.625     ,  0.05172414,  0.04166667],
#        [ 0.44117647,  0.29166667,  0.68965517,  0.75      ],
#        [ 1.        ,  0.33333333,  0.96551724,  0.79166667],
# ...

# %%
# logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=100.0)
lr.fit(X_train,y_train)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=100.0)

# %%
y_pred=lr.predict(X_test_std)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lr=LabelEncoder()
y=lr.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X_train)
X_train_std1=sc.transform(X_train)
X_test_std1=sc.transform(X_test)

# %%
X_test_std1
# Out:
# array([[-1.01235727,  0.78528012, -1.25527013, -1.28357488],
#        [ 0.72666135,  0.12476413,  1.04621827,  0.85943709],
#        [ 2.34146436,  1.66596811,  1.73666479,  1.39519009],
#        [-1.38500412,  0.34493613, -1.37034455, -1.28357488],
#        [-0.14284796, -1.19626785,  0.75853222,  1.12731359],
#        [ 0.85087697,  0.34493613,  0.81606943,  1.12731359],
#        [-0.88814165,  1.00545212, -1.31280734, -1.14963663],
#        [-1.2607885 ,  0.12476413, -1.19773292, -1.28357488],
#        [ 0.47823012,  0.78528012,  0.98868106,  1.52912833],
#        [-0.88814165,  1.66596811, -1.25527013, -1.14963663],
#        [ 0.60244574, -1.19626785,  0.75853222,  0.99337534],
#        [ 0.72666135,  0.34493613,  0.47084617,  0.45762235],
#        [-0.14284796, -0.53575186,  0.24069733,  0.18974585],
#        [ 0.22979889, -0.09540787,  0.6434578 ,  0.85943709],
#        [-1.2607885 , -0.09540787, -1.31280734, -1.14963663],
# ...

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(C=100.0)
lr.fit(X_train_std1,y_train)
# Out:
# LogisticRegression(C=100.0)

# %%
y_pred=lr.predict(X_test_std1)
y_pred
# Out:
# array([0, 2, 2, 0, 2, 2, 0, 0, 2, 0, 2, 1, 1, 2, 0, 2, 0, 0, 2, 2, 1, 1,
#        1, 0, 1, 2, 1, 1, 2, 2], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
round(accuracy_score(y_test,y_pred),2)
# Out:
# 0.97

# %%
from sklearn.svm import SVC

# %%
svm=SVC(kernel='rbf')
svm.fit(X_train_std1,y_train)
y_pred=svm.predict(X_test_std1)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9333333333333333

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(criterion='gini')
tree.fit(X_train_std1,y_train)
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# DecisionTreeClassifier()

# %%
y_pred=tree.predict(X_test_std1)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train_std1,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(X_test_std1)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9666666666666667

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train=pd.read_csv("train_loan_prediction.csv")

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64
