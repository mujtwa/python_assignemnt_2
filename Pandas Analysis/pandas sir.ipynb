# %%
 import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df1=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-eda2b5cc1a42> in <module>
# ----> 1 df1.head()
#
# NameError: name 'df1' is not defined

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
t=pd.read_csv(r"https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
t.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e38317572f1c> in <module>
# ----> 1 t.head()
#
# NameError: name 't' is not defined

# %%
df.shape # 891 rows and 15 columns
# Out:
# (891, 15)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.describe() # small statical these are the integer coolumns
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.dtypes[df.dtypes== 'object'].index
# Out:
# Index(['sex', 'embarked', 'who', 'embark_town', 'alive'], dtype='object')

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# sex            object
# embarked       object
# who            object
# embark_town    object
# alive          object
# dtype: object

# %%
df_1=df[df.dtypes[df.dtypes == 'object'].index] # datatypes of object

# %%
df_1
# Out:
#         sex embarked    who  embark_town alive
# 0      male        S    man  Southampton    no
# 1    female        C  woman    Cherbourg   yes
# 2    female        S  woman  Southampton   yes
# 3    female        S  woman  Southampton   yes
# 4      male        S    man  Southampton    no
# ..      ...      ...    ...          ...   ...
# 886    male        S    man  Southampton    no
# 887  female        S  woman  Southampton   yes
# 888  female        S  woman  Southampton    no
# 889    male        C    man    Cherbourg   yes
# 890    male        Q    man   Queenstown    no
#
# [891 rows x 5 columns]

# %%
df_1.describe()# description of the object variable
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df.columns # list of the columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
type(df['survived']) # this is series
# Out:
# pandas.core.series.Series

# %%
type(df[['pclass','sibsp']]) # this is a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df['survived'][5::-1] # indexing
# Out:
# 5    0
# 4    0
# 3    1
# 2    1
# 1    1
# 0    0
# Name: survived, dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['mujtaba']="Ali" # create a new columns

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone mujtaba
# 0    man        True  NaN  Southampton    no  False     Ali
# 1  woman       False    C    Cherbourg   yes  False     Ali
# 2  woman       False  NaN  Southampton   yes   True     Ali
# 3  woman       False    C  Southampton   yes  False     Ali
# 4    man        True  NaN  Southampton    no   True     Ali

# %%
df.dtypes == 'category'
# Out:
# survived       False
# pclass         False
# sex            False
# age            False
# sibsp          False
# parch          False
# fare           False
# embarked       False
# class           True
# who            False
# adult_male     False
# deck            True
# embark_town    False
# alive          False
# alone          False
# mujtaba        False
# dtype: bool

# %%
(df['pclass'])
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
pd.Categorical(df['pclass']) # it returns category of the columns
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['alive']) # for integer and categorical values
# Out:
# ['no', 'yes', 'yes', 'yes', 'no', ..., 'no', 'yes', 'no', 'yes', 'no']
# Length: 891
# Categories (2, object): ['no', 'yes']

# %%
pd.Categorical(df['mujtaba'])
# Out:
# ['Ali', 'Ali', 'Ali', 'Ali', 'Ali', ..., 'Ali', 'Ali', 'Ali', 'Ali', 'Ali']
# Length: 891
# Categories (1, object): ['Ali']

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# mujtaba          object
# dtype: object

# %%
df['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
df['pclass'].isnull() # returns true where we have null value
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: pclass, Length: 891, dtype: bool

# %%
df['pclass'].isnull().sum() # there is no null value here
# Out:
# 0

# %%
import numpy as np

# %%
df['pclass'].isnull() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: pclass, Length: 891, dtype: bool

# %%
np.where(df['pclass'].isnull() == True)
# Out:
# (array([], dtype=int64),)

# %%
df['pclass'][6]
# Out:
# 1

# %%
np.where(df['alive'].isnull() == True)
# Out:
# (array([], dtype=int64),)

# %%
np.where(df['fare']==max(df['fare'])) # maximum fare
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
d=np.where(df['sex']=='male')
df.iloc[d]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone mujtaba
# ...

# %%
df['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'mujtaba'],
#       dtype='object')

# %%
 df.iloc[0:2]  # integer location
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone mujtaba
# 0    man        True  NaN  Southampton    no  False     Ali
# 1  woman       False    C    Cherbourg   yes  False     Ali

# %%
 df.iloc[[0,1,2]]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone mujtaba
# 0    man        True  NaN  Southampton    no  False     Ali
# 1  woman       False    C    Cherbourg   yes  False     Ali
# 2  woman       False  NaN  Southampton   yes   True     Ali

# %%
np.where(df['fare'] == max(df['fare']))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
df.iloc[np.where(df['fare'] == max(df['fare']))]['sex'] # maximum fare

# %%
len(df.iloc[np.where(df['survived'] == 1)]['sex']) # 342 survived
# Out:
# 342

# %%
labels=['a','b','c','d'] # categorical list
list_1 = [34,23,34]
array = np.array(list_1)
d={'a':45,'b':67,'c':44}

# %%
s1=pd.Series(list_1,index=['a','b','c']) # we can convert our list into a series

# %%
s1
# Out:
# a    34
# b    23
# c    34
# dtype: int64

# %%
s1[0] # by default index  number
# Out:
# 34

# %%
s1['a'] # by given inex number
# Out:
# 34

# %%
array
# Out:
# array([34, 23, 34])

# %%
pd.Series(array)
# Out:
# 0    34
# 1    23
# 2    34
# dtype: int32

# %%
d
# Out:
# {'a': 45, 'b': 67, 'c': 44}

# %%
dd=pd.Series(d) #

# %%
dd[0] # by default indexes
# Out:
# 45

# %%
dd['a'] # access by named indexes
# Out:
# 45

# %%
s2=pd.Series([1,2,3,4,5,6,7],index=['a','b','c','d','e','f','g'])

# %%
s2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# g    7
# dtype: int64

# %%
s3=pd.Series([1,2,30,42,5,6,7],index=['a','b','c','c','e','f','g'])

# %%
s3
# Out:
# a     1
# b     2
# c    30
# c    42
# e     5
# f     6
# g     7
# dtype: int64

# %%
s2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# g    7
# dtype: int64

# %%
s3['c'] # returns both data by named index
# Out:
# c    30
# c    42
# dtype: int64

# %%
s3[3]
# Out:
# 42

# %%
s4=s2+s3

# %%
s3
# Out:
# a     1
# b     2
# c    30
# c    42
# e     5
# f     6
# g     7
# dtype: int64

# %%
s3.iloc[1] # integer location
# Out:
# 2

# %%
s3.iloc[3]
# Out:
# 42

# %%
s3.loc['a']
# Out:
# 1

# %%
s3.loc['b'] # by named indexes
# Out:
# 2

# %%
 from numpy.random import randn as rn

# %%
rn(3,4)             # row 3 and coolumn 4
# Out:
# array([[-0.46789903, -1.17965565, -1.4550862 ,  0.16677219],
#        [-0.16108549, -1.65116315, -1.09575619,  1.98648739],
#        [ 0.17859389, -0.97338443, -0.46876675, -0.8402735 ]])

# %%
pd.DataFrame(rn(5,5)) # convert into DataFrame
# Out:
#           0         1         2         3         4
# 0  0.254106 -0.483524 -0.375826 -0.881691 -0.709372
# 1  0.475115 -0.601273 -1.001764  0.294243  0.536510
# 2 -0.341871 -0.471798  0.365831 -0.612018  0.920094
# 3 -1.948866 -1.260276 -1.047509 -0.897186 -0.275556
# 4  0.349886  0.813880 -1.452023 -1.157354 -0.754623

# %%
pd.DataFrame(rn(5,5),index=['a','b','d','e','f'])# named index
# Out:
#           0         1         2         3         4
# a  1.693249  0.534791  0.793580  0.680349  1.250465
# b  0.180356  0.655699  0.165513 -0.325060 -2.880690
# d -3.206388  0.283710  0.882480 -0.318782  0.715744
# e -1.302331  0.182606  0.242262 -0.530383 -0.333611
# f -0.552330  0.158308  1.691661 -0.987612  1.222468

# %%
df2=pd.DataFrame(rn(5,5),index=['a','b','d','e','f'],columns=['x','y','z','u','v'])

# %%
df2
# Out:
#           x         y         z         u         v
# a -0.613884 -0.956670 -0.870304 -0.783598  0.460415
# b  0.453272 -1.161244  0.571001  0.409751  3.145204
# d -1.149392 -0.280774 -0.208675 -1.041074 -1.215475
# e  0.257540 -0.433799  0.248768 -1.227661  1.043144
# f  1.645663  0.024248  1.263103  1.408797  1.288815

# %%
df2.loc['a']
# Out:
# x   -0.613884
# y   -0.956670
# z   -0.870304
# u   -0.783598
# v    0.460415
# Name: a, dtype: float64

# %%
df2.iloc[[0,1,2]]
# Out:
#           x         y         z         u         v
# a -0.613884 -0.956670 -0.870304 -0.783598  0.460415
# b  0.453272 -1.161244  0.571001  0.409751  3.145204
# d -1.149392 -0.280774 -0.208675 -1.041074 -1.215475

# %%
df2.iloc[3:1:-1]
# Out:
#           x         y         z         u         v
# e  0.257540 -0.433799  0.248768 -1.227661  1.043144
# d -1.149392 -0.280774 -0.208675 -1.041074 -1.215475

# %%
df2
# Out:
#           x         y         z         u         v
# a -0.613884 -0.956670 -0.870304 -0.783598  0.460415
# b  0.453272 -1.161244  0.571001  0.409751  3.145204
# d -1.149392 -0.280774 -0.208675 -1.041074 -1.215475
# e  0.257540 -0.433799  0.248768 -1.227661  1.043144
# f  1.645663  0.024248  1.263103  1.408797  1.288815

# %%
df2.loc['a']
# Out:
# x   -0.613884
# y   -0.956670
# z   -0.870304
# u   -0.783598
# v    0.460415
# Name: a, dtype: float64

# %%
df2.loc['d']
# Out:
# x   -1.149392
# y   -0.280774
# z   -0.208675
# u   -1.041074
# v   -1.215475
# Name: d, dtype: float64

# %%
df2.loc[['a','b']]
# Out:
#           x         y         z         u         v
# a -0.613884 -0.956670 -0.870304 -0.783598  0.460415
# b  0.453272 -1.161244  0.571001  0.409751  3.145204

# %%
df2['new_column'] = df2['x']+df2['y']

# %%
df2
# Out:
#           x         y         z         u         v  new_column
# a -0.613884 -0.956670 -0.870304 -0.783598  0.460415   -1.570555
# b  0.453272 -1.161244  0.571001  0.409751  3.145204   -0.707971
# d -1.149392 -0.280774 -0.208675 -1.041074 -1.215475   -1.430166
# e  0.257540 -0.433799  0.248768 -1.227661  1.043144   -0.176259
# f  1.645663  0.024248  1.263103  1.408797  1.288815    1.669911

# %%
df2['new_column_mult'] = df2['x']*df2['y']

# %%
df2
# Out:
#           x         y         z         u         v  new_column  \
# a -0.613884 -0.956670 -0.870304 -0.783598  0.460415   -1.570555
# b  0.453272 -1.161244  0.571001  0.409751  3.145204   -0.707971
# d -1.149392 -0.280774 -0.208675 -1.041074 -1.215475   -1.430166
# e  0.257540 -0.433799  0.248768 -1.227661  1.043144   -0.176259
# f  1.645663  0.024248  1.263103  1.408797  1.288815    1.669911
#
#    new_column_mult
# a         0.587285
# b        -0.526360
# d         0.322719
# e        -0.111721
# f         0.039903

# %%
df2['a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-bc9431a2696d> in <module>
# ----> 1 df2['a']
#
# ...

# %%
df2.drop('x',axis=1,inplace=True) # axis == 0 #means row by default

# %%
df2
# Out:
#           y         z         u         v  new_column  new_column_mult
# a -0.956670 -0.870304 -0.783598  0.460415   -1.570555         0.587285
# b -1.161244  0.571001  0.409751  3.145204   -0.707971        -0.526360
# d -0.280774 -0.208675 -1.041074 -1.215475   -1.430166         0.322719
# e -0.433799  0.248768 -1.227661  1.043144   -0.176259        -0.111721
# f  0.024248  1.263103  1.408797  1.288815    1.669911         0.039903

# %%
df2.drop('e',inplace=True)

# %%
df2
# Out:
#           y         z         u         v  new_column  new_column_mult
# a -0.956670 -0.870304 -0.783598  0.460415   -1.570555         0.587285
# b -1.161244  0.571001  0.409751  3.145204   -0.707971        -0.526360
# d -0.280774 -0.208675 -1.041074 -1.215475   -1.430166         0.322719
# f  0.024248  1.263103  1.408797  1.288815    1.669911         0.039903

# %%
df2.drop(['a','b'])
# Out:
#           y         z         u         v  new_column  new_column_mult
# d -0.280774 -0.208675 -1.041074 -1.215475   -1.430166         0.322719
# f  0.024248  1.263103  1.408797  1.288815    1.669911         0.039903

# %%
df2.drop(['y','z'],axis=1)
# Out:
#           u         v  new_column  new_column_mult
# a -0.783598  0.460415   -1.570555         0.587285
# b  0.409751  3.145204   -0.707971        -0.526360
# d -1.041074 -1.215475   -1.430166         0.322719
# f  1.408797  1.288815    1.669911         0.039903

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
nd=np.where(df['age'].isnull()== True)

# %%
df.drop(nd[0])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.shape
# Out:
# (891, 16)

# %%
df2
# Out:
#           y         z         u         v  new_column  new_column_mult
# a -0.956670 -0.870304 -0.783598  0.460415   -1.570555         0.587285
# b -1.161244  0.571001  0.409751  3.145204   -0.707971        -0.526360
# d -0.280774 -0.208675 -1.041074 -1.215475   -1.430166         0.322719
# f  0.024248  1.263103  1.408797  1.288815    1.669911         0.039903

# %%
df2.loc[['a','b'],['new_column','new_column_mult']]
# Out:
#    new_column  new_column_mult
# a   -1.570555         0.587285
# b   -0.707971        -0.526360

# %%
df2.iloc[[0,1],[4,5]]
# Out:
#    new_column  new_column_mult
# a   -1.570555         0.587285
# b   -0.707971        -0.526360

# %%
df2.iloc[0:2,4:]
# Out:
#    new_column  new_column_mult
# a   -1.570555         0.587285
# b   -0.707971        -0.526360

# %%
df2[df2>0]
# Out:
#           y         z         u         v  new_column  new_column_mult
# a       NaN       NaN       NaN  0.460415         NaN         0.587285
# b       NaN  0.571001  0.409751  3.145204         NaN              NaN
# d       NaN       NaN       NaN       NaN         NaN         0.322719
# f  0.024248  1.263103  1.408797  1.288815    1.669911         0.039903

# %%
df2
# Out:
#           y         z         u         v  new_column  new_column_mult
# a -0.956670 -0.870304 -0.783598  0.460415   -1.570555         0.587285
# b -1.161244  0.571001  0.409751  3.145204   -0.707971        -0.526360
# d -0.280774 -0.208675 -1.041074 -1.215475   -1.430166         0.322719
# f  0.024248  1.263103  1.408797  1.288815    1.669911         0.039903

# %%
df2[df2['z']<0]
# Out:
#           y         z         u         v  new_column  new_column_mult
# a -0.956670 -0.870304 -0.783598  0.460415   -1.570555         0.587285
# d -0.280774 -0.208675 -1.041074 -1.215475   -1.430166         0.322719

# %%
df2[(df2['z']<0) & (df2['v']< 0)]

# %%
df2.reset_index(inplace=True) # after applying this we get default indexes

# %%
df2

# %%
df2.set_index('z') # z column becomes index

# %%
import pandas as pd

# %%
import numpy as np

# %%
labels=['a','b','c','d'] # categorical list
list_1 = [34,23,34]
array = np.array(list_1)
d={'a':45,'b':67,'c':44}

# %%
type(pd.DataFrame(labels)) # this is data frame
# Out:
# pandas.core.frame.DataFrame

# %%
data={'A':[1,2,5],'B':[np.nan,np.nan,3],'C':[2,4,3]}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    A    B  C
# 0  1  NaN  2
# 1  2  NaN  4
# 2  5  3.0  3

# %%
df.drop(0,inplace=True) # not a parmanent deletion,

# %%
df
# Out:
#    A    B  C
# 1  2  NaN  4
# 2  5  3.0  3

# %%
df
# Out:
#    A    B  C
# 1  2  NaN  4
# 2  5  3.0  3

# %%
df.drop('A',axis=1,inplace=True)

# %%
df
# Out:
#      B  C
# 1  NaN  4
# 2  3.0  3

# %%
df.dropna() # it  deletes   the rows where we have any null value
# Out:
#      B  C
# 2  3.0  3

# %%
df
# Out:
#      B  C
# 1  NaN  4
# 2  3.0  3

# %%
df.dropna(axis=1) # it will delete column wise and axis=0
# Out:
#    C
# 1  4
# 2  3

# %%
df
# Out:
#      B  C
# 1  NaN  4
# 2  3.0  3

# %%
df.dropna(axis=1,thresh=2)
# Out:
#    C
# 1  4
# 2  3

# %%
df
# Out:
#      B  C
# 1  NaN  4
# 2  3.0  3

# %%
df
# Out:
#      B  C
# 1  NaN  4
# 2  3.0  3

# %%
df.fillna(1) # null replaced by 1
# Out:
#      B  C
# 1  1.0  4
# 2  3.0  3

# %%
 #df.fillna(df['B'].mean())
import pandas as pd

# %%
df=pd.read_csv(r"https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dropna(thresh=5)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
g=df.groupby('Sex') # returns an object

# %%
g.mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
g=df.groupby('Pclass')

# %%
g.mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g.median()
# Out:
#         PassengerId  Survived   Age  SibSp  Parch     Fare
# Pclass
# 1             472.0       1.0  37.0    0.0    0.0  60.2875
# 2             435.5       0.0  29.0    0.0    0.0  14.2500
# 3             432.0       0.0  24.0    0.0    0.0   8.0500

# %%
g.sum() # total
# Out:
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136  7111.42     90     77  18177.4125
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951

# %%
g.sum()[['Fare','Survived']]
# Out:
#               Fare  Survived
# Pclass
# 1       18177.4125       136
# 2        3801.8417        87
# 3        6714.6951       119

# %%
g.mean()[['Fare','Survived']]
# Out:
#              Fare  Survived
# Pclass
# 1       84.154687  0.629630
# 2       20.662183  0.472826
# 3       13.675550  0.242363

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
f=df.groupby('Survived')

# %%
f.mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
f.sum()
# Out:
#           PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0              245412    1390  12985.50    304    181  12142.7199
# 1              151974     667   8219.67    162    159  16551.2294

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=df.iloc[0:5,0:5]

# %%
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df1.transpose()
# Out:
#                                    0  \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
#
#                                                              1  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
#
#                                   2  \
# PassengerId                       3
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
#
#                                                         3  \
# PassengerId                                             4
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df2=df1

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df3=df2

# %%
df3
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df4=pd.concat([df1,df2,df3]) # by default row wise

# %%
pd.concat([df1,df2,df3],axis=1) # concat columns wise
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  PassengerId  \
# 0                            Braund, Mr. Owen Harris    male            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female            2
# 2                             Heikkinen, Miss. Laina  female            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female            4
# 4                           Allen, Mr. William Henry    male            5
#
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# ...

# %%
df4.iloc[5]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Name: 0, dtype: object

# %%
pd.concat([df1,df2,df3])
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# ...

# %%
df4.loc[0] # named indexes
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex
# 0            1         0       3  Braund, Mr. Owen Harris  male
# 0            1         0       3  Braund, Mr. Owen Harris  male
# 0            1         0       3  Braund, Mr. Owen Harris  male

# %%
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
pd.merge(df1,df2,on='PassengerId')
# Out:
#    PassengerId  Survived_x  Pclass_x  \
# 0            1           0         3
# 1            2           1         1
# 2            3           1         3
# 3            4           1         1
# 4            5           0         3
#
#                                               Name_x   Sex_x  Survived_y  \
# 0                            Braund, Mr. Owen Harris    male           0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           1
# 2                             Heikkinen, Miss. Laina  female           1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           1
# 4                           Allen, Mr. William Henry    male           0
#
#    Pclass_y                                             Name_y   Sex_y
# 0         3                            Braund, Mr. Owen Harris    male
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2         3                             Heikkinen, Miss. Laina  female
# ...

# %%
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df1.join(df2,lsuffix="-1")
# Out:
#    PassengerId-1  Survived-1  Pclass-1  \
# 0              1           0         3
# 1              2           1         1
# 2              3           1         3
# 3              4           1         1
# 4              5           0         3
#
#                                               Name-1   Sex-1  PassengerId  \
# 0                            Braund, Mr. Owen Harris    male            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female            2
# 2                             Heikkinen, Miss. Laina  female            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female            4
# 4                           Allen, Mr. William Henry    male            5
#
#    Survived  Pclass                                               Name     Sex
# 0         0       3                            Braund, Mr. Owen Harris    male
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dropna(thresh=2,axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['len_name']=df['Name'].apply(len) # apply is a function it contains only fuction

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  len_name
# 0      0         A/5 21171   7.2500   NaN        S        23
# 1      0          PC 17599  71.2833   C85        C        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S        22
# 3      0            113803  53.1000  C123        S        44
# ...

# %%
df['Suare_fare']=df['Fare'].apply(np.sqrt)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  len_name  Suare_fare
# 0      0         A/5 21171   7.2500   NaN        S        23    2.692582
# 1      0          PC 17599  71.2833   C85        C        51    8.442944
# 2      0  STON/O2. 3101282   7.9250   NaN        S        22    2.815138
# ...

# %%
def test(x):
    return len(x)

# %%
df['square_new']= df['Name'].apply(test) # external function

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  len_name  Suare_fare  \
# 0      0         A/5 21171   7.2500   NaN        S        23    2.692582
# 1      0          PC 17599  71.2833   C85        C        51    8.442944
# 2      0  STON/O2. 3101282   7.9250   NaN        S        22    2.815138
# ...

# %%
def test1(x):
    if x== 'female':
        return 0
    else:
        return 1

# %%
df['flag']= df['Sex'].apply(test1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values("Fare") # this is function sort_values()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...

# %%
## Numpy library -> numerical python

# %%
import numpy as np

# %%
a=np.array([1,2,3,56,3,43])

# %%
a
# Out:
# array([ 1,  2,  3, 56,  3, 43])

# %%
type(a) # numpy nd array
# Out:
# numpy.ndarray

# %%
np.array([23,34.2432,"jhasf",23],ndmin=3)# 3rd dimensional arrya
# Out:
# array([[['23', '34.2432', 'jhasf', '23']]], dtype='<U32')

# %%
np.array([23,34.2432,"jhasf",23],ndmin=2) # 2 nd array dimensional array
# Out:
# array([['23', '34.2432', 'jhasf', '23']], dtype='<U32')

# %%
_2d=np.array([[1,2,3],[4,5,6],[7,8,6],[8,6,5]],ndmin=3)

# %%
_2d
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 6],
#         [8, 6, 5]]])
