# %%
 # pandas 
    # file read and write operation

# %%
import pandas as pd

# %%
type(pd.read_csv(r"C:\Users\asus\Internshala\variance.csv"))
# Out:
# pandas.core.frame.DataFrame

# %%
# type is a frame

# %%
df=pd.read_csv(r"C:\Users\asus\Internshala\variance.csv")

# %%
df.head()
# Out:
#    Student  Overall Marks Gender    Subject
# 0    Anish           9700   Male    English
# 1  Rishabh             83   Male    English
# 2     Ajay             78   Male    Physics
# 3  Abhinav             86   Male  Chemistry
# 4   Anurag             91   Male    English

# %%
df.head(10)
# Out:
#    Student  Overall Marks  Gender    Subject
# 0    Anish           9700    Male    English
# 1  Rishabh             83    Male    English
# 2     Ajay             78    Male    Physics
# 3  Abhinav             86    Male  Chemistry
# 4   Anurag             91    Male    English
# 5    Ajeet             15    Male    Physics
# 6    Varun             83    Male  Chemistry
# 7   Rajeev             64    Male  Chemistry
# 8   sanjay             66    Male  Chemistry
# 9    NISHA             58  Female    Physics

# %%
df.tail(10)
# Out:
#     Student  Overall Marks  Gender    Subject
# 90   vedant             74    Male    English
# 91      Ram             99    Male    Physics
# 92     Dawn             73  Female    Physics
# 93    ankur             17    Male  Chemistry
# 94   Smriti              0  Female  Chemistry
# 95  Aaditya             77    Male  Chemistry
# 96    vivek             55    Male    Physics
# 97    Tisha              7  Female    English
# 98   Raghav             73    Male    English
# 99   Ishita             82  Female  Chemistry

# %%
df=pd.read_csv(r"C:\Users\asus\Internshala\variance.csv",sep=",")

# %%
df
# Out:
#     Student  Overall Marks  Gender    Subject
# 0     Anish           9700    Male    English
# 1   Rishabh             83    Male    English
# 2      Ajay             78    Male    Physics
# 3   Abhinav             86    Male  Chemistry
# 4    Anurag             91    Male    English
# ..      ...            ...     ...        ...
# 95  Aaditya             77    Male  Chemistry
# 96    vivek             55    Male    Physics
# 97    Tisha              7  Female    English
# 98   Raghav             73    Male    English
# 99   Ishita             82  Female  Chemistry
#
# [100 rows x 4 columns]

# %%
pd.read_table(r"C:\Users\asus\Internshala\variance.csv",sep=" ")
# Out:
#               Student,Overall  Marks,Gender,Subject
# 0     Anish,9700,Male,English                   NaN
# 1     Rishabh,83,Male,English                   NaN
# 2          Ajay,,Male,Physics                   NaN
# 3   Abhinav,86,Male,Chemistry                   NaN
# 4      Anurag,91,Male,English                   NaN
# ..                        ...                   ...
# 95  Aaditya,77,Male,Chemistry                   NaN
# 96                vivek,Male,                   NaN
# 97     Tisha,7,Female,English                   NaN
# 98            73,Male,English                   NaN
# 99    Ishita,Female,Chemistry                   NaN
#
# [100 rows x 2 columns]

# %%
pd.read_csv(r"C:\Users\asus\Internshala\variance.csv",header=None)
# Out:
#            0              1       2          3
# 0    Student  Overall Marks  Gender    Subject
# 1      Anish           9700    Male    English
# 2    Rishabh             83    Male    English
# 3       Ajay             78    Male    Physics
# 4    Abhinav             86    Male  Chemistry
# ..       ...            ...     ...        ...
# 96   Aaditya             77    Male  Chemistry
# 97     vivek             55    Male    Physics
# 98     Tisha              7  Female    English
# 99    Raghav             73    Male    English
# 100   Ishita             82  Female  Chemistry
#
# [101 rows x 4 columns]

# %%
df
# Out:
#            0              1       2          3
# 0    Student  Overall Marks  Gender    Subject
# 1      Anish           9700    Male    English
# 2    Rishabh             83    Male    English
# 3       Ajay             78    Male    Physics
# 4    Abhinav             86    Male  Chemistry
# ..       ...            ...     ...        ...
# 96   Aaditya             77    Male  Chemistry
# 97     vivek             55    Male    Physics
# 98     Tisha              7  Female    English
# 99    Raghav             73    Male    English
# 100   Ishita             82  Female  Chemistry
#
# [101 rows x 4 columns]

# %%
# give your own columns names

# %%
pd.read_csv(r"C:\Users\asus\Internshala\variance.csv",names=['a','b','c','d'])
# Out:
#            a              b       c          d
# 0    Student  Overall Marks  Gender    Subject
# 1      Anish           9700    Male    English
# 2    Rishabh             83    Male    English
# 3       Ajay             78    Male    Physics
# 4    Abhinav             86    Male  Chemistry
# ..       ...            ...     ...        ...
# 96   Aaditya             77    Male  Chemistry
# 97     vivek             55    Male    Physics
# 98     Tisha              7  Female    English
# 99    Raghav             73    Male    English
# 100   Ishita             82  Female  Chemistry
#
# [101 rows x 4 columns]

# %%
pd.read_csv(r"C:\Users\asus\Internshala\variance.csv")
# Out:
#     Student Overall Marks     Gender    Subject
# 0     Anish          9700       Male    English
# 1   Rishabh            83       Male    English
# 2      Ajay           NaN       Male    Physics
# 3   Abhinav            86       Male  Chemistry
# 4    Anurag            91       Male    English
# ..      ...           ...        ...        ...
# 95  Aaditya            77       Male  Chemistry
# 96    vivek          Male        NaN        NaN
# 97    Tisha             7     Female    English
# 98       73          Male    English        NaN
# 99   Ishita        Female  Chemistry        NaN
#
# [100 rows x 4 columns]

# %%
pd.read_csv(r"C:\Users\asus\Internshala\variance.csv",names=['a','b','c','d','4','23we'])
# Out:
#            a              b       c          d   4  23we
# 0    Student  Overall Marks  Gender    Subject NaN   NaN
# 1      Anish           9700    Male    English NaN   NaN
# 2    Rishabh             83    Male    English NaN   NaN
# 3       Ajay             78    Male    Physics NaN   NaN
# 4    Abhinav             86    Male  Chemistry NaN   NaN
# ..       ...            ...     ...        ...  ..   ...
# 96   Aaditya             77    Male  Chemistry NaN   NaN
# 97     vivek             55    Male    Physics NaN   NaN
# 98     Tisha              7  Female    English NaN   NaN
# 99    Raghav             73    Male    English NaN   NaN
# 100   Ishita             82  Female  Chemistry NaN   NaN
#
# [101 rows x 6 columns]

# %%
df=pd.read_csv(r"C:\Users\asus\Internshala\variance.csv",index_col=['key1','key2'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-ff277440c6d4> in <module>
# ----> 1 df=pd.read_csv(r"C:\Users\asus\Internshala\variance.csv",index_col=['key1','key2'])
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
pd.read_csv(r"C:\Users\asus\Internshala\variance.csv",index_col=['Male','Female'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-41d399d2a7c7> in <module>
# ----> 1 pd.read_csv(r"C:\Users\asus\Internshala\variance.csv",index_col=['Male','Female'])
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
t=pd.read_csv(r"C:\Users\asus\Internshala\variance.csv")

# %%
pd.isnull(t)
# Out:
#     Student  Overall Marks  Gender  Subject
# 0     False          False   False    False
# 1     False          False   False    False
# 2     False          False   False    False
# 3     False          False   False    False
# 4     False          False   False    False
# ..      ...            ...     ...      ...
# 95    False          False   False    False
# 96    False          False   False    False
# 97    False          False   False    False
# 98    False          False   False    False
# 99    False          False   False    False
#
# [100 rows x 4 columns]

# %%
df1=pd.read_csv(r"C:\Users\asus\Internshala\variance.csv")

# %%
df1
# Out:
#     Student Overall Marks     Gender    Subject
# 0     Anish          9700       Male    English
# 1   Rishabh            83       Male    English
# 2      Ajay           NaN       Male    Physics
# 3   Abhinav            86       Male  Chemistry
# 4    Anurag            91       Male    English
# ..      ...           ...        ...        ...
# 95  Aaditya            77       Male  Chemistry
# 96    vivek          Male        NaN        NaN
# 97    Tisha             7     Female    English
# 98       73          Male    English        NaN
# 99   Ishita        Female  Chemistry        NaN
#
# [100 rows x 4 columns]

# %%
pd.isnull(df1)
# Out:
#     Student  Overall Marks  Gender  Subject
# 0     False          False   False    False
# 1     False          False   False    False
# 2     False           True   False    False
# 3     False          False   False    False
# 4     False          False   False    False
# ..      ...            ...     ...      ...
# 95    False          False   False    False
# 96    False          False    True     True
# 97    False          False   False    False
# 98    False          False   False     True
# 99    False          False   False     True
#
# [100 rows x 4 columns]

# %%
url="https://www.basketball-reference.com/boxscores/?month=6&day=7&year=2021"
data=pd.read_html(url)

# %%
type(data)
# Out:
# list

# %%
df=data[0]

# %%
df.head()
# Out:
#            0    1      2
# 0  Milwaukee   86  Final
# 1   Brooklyn  125    NaN

# %%
df.tail(1)
# Out:
#           0    1    2
# 1  Brooklyn  125  NaN

# %%
type(df1['Student']) # read one single columns & this is a series
# Out:
# pandas.core.series.Series

# %%
df1.columns
# Out:
# Index(['Student', 'Overall Marks', 'Gender', 'Subject'], dtype='object')

# %%
df1[['Student','Overall Marks']] # more than 1 colums then pass in list
# Out:
#     Student Overall Marks
# 0     Anish          9700
# 1   Rishabh            83
# 2      Ajay           NaN
# 3   Abhinav            86
# 4    Anurag            91
# ..      ...           ...
# 95  Aaditya            77
# 96    vivek          Male
# 97    Tisha             7
# 98       73          Male
# 99   Ishita        Female
#
# [100 rows x 2 columns]

# %%
type(df1[['Student']]) # data frame
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['Student', 'Overall Marks', 'Gender', 'Subject'], dtype='object')

# %%
import seaborn as sb

# %%
df=sb.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df_bank=pd.read_csv(r"https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv",sep=";")

# %%
df_bank.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df_bank.shape
# Out:
# (41188, 21)

# %%
df_bank.tail(2)
# Out:
#        age         job  marital            education default housing loan  \
# 41186   44  technician  married  professional.course      no      no   no
# 41187   74     retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [2 rows x 21 columns]

# %%
df_bank.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df_bank['age'].dtype
# Out:
# dtype('int64')

# %%
df_bank['job']
# Out:
# 0          housemaid
# 1           services
# 2           services
# 3             admin.
# 4           services
#             ...
# 41183        retired
# 41184    blue-collar
# 41185        retired
# 41186     technician
# 41187        retired
# Name: job, Length: 41188, dtype: object

# %%
df_bank.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df_bank=pd.read_csv(r"https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv",sep=";",names=['Age', 'job_DataScientist', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
       'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'])
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,10,11,12,13,15,16,17,18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_bank.head()
# Out:
#    Age job_DataScientist  marital    education  default  housing  loan  \
# 0  age               job  marital    education  default  housing  loan
# 1   56         housemaid  married     basic.4y       no       no    no
# 2   57          services  married  high.school  unknown       no    no
# 3   37          services  married  high.school       no      yes    no
# 4   40            admin.  married     basic.6y       no       no    no
#
#      contact  month  day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0    contact  month  day_of_week  ...  campaign  pdays  previous     poutcome
# 1  telephone    may          mon  ...         1    999         0  nonexistent
# 2  telephone    may          mon  ...         1    999         0  nonexistent
# 3  telephone    may          mon  ...         1    999         0  nonexistent
# 4  telephone    may          mon  ...         1    999         0  nonexistent
#
# ...

# %%
# JSON DATA reading json

# %%
pd.read_csv("C:/Users/asus/Documents/MSOFFICE/Excel/banglore.csv")
# Out:
#              Unnamed: 0       balcony      Values    Unnamed: 3 Unnamed: 4  \
# 0                   NaN       (blank)         NaN             3        NaN
# 1             area_type  Sum of price   Sum of gp  Sum of price  Sum of gp
# 2        Built-up  Area     21979.785   6593.9355      40292.28  12087.684
# 3          Carpet  Area          1082       324.6        1531.8     459.54
# 4            Plot  Area      61121.75   18336.525       68574.5   20572.35
# 5  Super built-up  Area     67072.125  20121.6375     141653.36  42496.008
# 6           areaandplot      62203.75   18661.125       70106.3   21031.89
# 7           Grand Total     213459.41   64037.823     322158.24  96647.472
#
#      Unnamed: 5  Unnamed: 6    Unnamed: 7 Unnamed: 8    Unnamed: 9  \
# 0             2         NaN             1        NaN             0
# 1  Sum of price   Sum of gp  Sum of price  Sum of gp  Sum of price
# 2      82805.24   24841.572       72183.3   21654.99      34901.73
# ...

# %%
import pandas as pd

# %%
url=pd.read_html('https://www.basketball-reference.com/leagues/')

# %%
df=url[0]

# %%
df.head(3)
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0  Unnamed: 2_level_0     Award Winners  \
#               Season                 Lg            Champion               MVP
# 0            2020-21                NBA                 NaN               NaN
# 1            2019-20                NBA  Los Angeles Lakers  G. Antetokounmpo
# 2            2018-19                NBA     Toronto Raptors  G. Antetokounmpo
#
#                         Top Performers                      \
#   Rookie of the Year            Points            Rebounds
# 0                NaN   S. Curry (2015)     R. Gobert (960)
# 1          J. Morant  J. Harden (2335)     R. Gobert (916)
# 2          L. Dončić  J. Harden (2818)  A. Drummond (1232)
#
#
#               Assists        Win Shares
# 0  R. Westbrook (763)   N. Jokić (15.6)
# 1      L. James (684)  J. Harden (13.1)
# 2  R. Westbrook (784)  J. Harden (15.2)
